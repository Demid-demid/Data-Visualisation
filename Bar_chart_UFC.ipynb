# %%
import pandas as pd
import seaborn as sb
import numpy as np 
import matplotlib.pyplot as plt 

from numpy.random import randn

# %matplotlib inline

# %%
UFC = pd.read_csv("/Users/demiddemidov/Desktop/D/my projects/Data Visualization/DeepUFC2/ufc_fighters.csv",)
print(UFC.shape)
UFC.head()
# Out:
# (3187, 20)
#    fighter_id             name  win  lose  draw  nc  height    weight reach  \
# 0           1  Luciano Azevedo   16     9     1   0   6' 3"  161 lbs.   NaN
# 1           2   Michael Byrnes    5     2     0   0  5' 11"  155 lbs.   NaN
# 2           3   Gleidson Cutis    7     3     0   0   5' 9"  155 lbs.   NaN
# 3           4       Rolando Dy    9     7     1   1   5' 8"  145 lbs.   69"
# 4           5      Jessica Eye   13     6     0   1   5' 6"  125 lbs.   66"
#
#      stance           dob  SLpM Str_Acc  SApM Str_Def  TD_Avg TD_Acc TD_Def  \
# 0  Orthodox  Jun 25, 1981  0.76     45%  1.97     27%    2.28    11%     0%
# 1       NaN  Jul 17, 1990  0.00      0%  0.00      0%    0.00     0%     0%
# 2  Orthodox  Feb 07, 1989  2.99     52%  8.28     59%    0.00     0%     0%
# 3  Orthodox  Aug 11, 1990  3.04     37%  4.47     52%    0.30    20%    68%
# 4  Orthodox  Jul 27, 1986  3.42     36%  3.32     59%    0.59    71%    60%
#
#    Sub_Avg                last_updated
# ...

# %%
base_color = sb.color_palette()[0] # changing the color of the graph
sb.countplot(x="stance", data=UFC, color=base_color)
#Cheking diferent stance

# %%
sb.countplot(y="stance", data=UFC )
#plt.xticks(rotation = 90) <---- No needet if we use y = veriable
#Rotation of the xticks 
#Cheking diferent stance

# %%
UFC.head()
sb.countplot(y="Str_Acc", data=UFC )

# %%
pk= pd.read_csv("/Users/demiddemidov/Desktop/D/my projects/Data Visualization/Quizzes/pokemon.csv")
pk.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
pk_types=pk.melt(id_vars=["id","species"], value_vars = ["type_1", "type_2"], var_name="type_level", value_name = "type").dropna() # Dropna to drop all the columns with out data 

pk_types[802:812]
# Out:
#       id      species type_level      type
# 802  803      poipole     type_1    poison
# 803  804    naganadel     type_1    poison
# 804  805    stakataka     type_1      rock
# 805  806  blacephalon     type_1      fire
# 806  807      zeraora     type_1  electric
# 807    1    bulbasaur     type_2    poison
# 808    2      ivysaur     type_2    poison
# 809    3     venusaur     type_2    poison
# 812    6    charizard     type_2    flying
# 818   12   butterfree     type_2    flying

# %%
type_counts = pk_types["type"].value_counts() # to  count all the unic values 
type_order = type_counts.index  #?????????????????

# %%
sb.countplot(data= pk_types, y="type", color =base_color, order = type_order)

# %%
n_pk = pk.shape[0]
max_type_count = type_counts[0]
max_prop = max_type_count / n_pk#?????????????????
print(max_prop)
# Out:
# 0.1623296158612144

# %%
tick_props = np.arange(0, max_prop,0.02) #?????????????????
tick_names = ["{:0.2f}".format(v) for v in tick_props]#?????????????????

# %%
sb.countplot(data= pk_types, y="type", color =base_color, order = type_order)
plt.xticks(tick_props * n_pk, tick_names) #?????????????????
plt.xlabel("proportion")
