# %%
import pandas as pd
import seaborn as sb
import numpy as np 
import matplotlib.pyplot as plt 

from numpy.random import randn

# %matplotlib inline

# %%
x=randn(100)
sb.distplot(x, bins=10)
#kde= False to cancel the line

# %%
sb.kdeplot(x,shade= True,)
