# %%
import pandas as pd
import seaborn as sb
import numpy as np 
import matplotlib.pyplot as plt 


# %matplotlib inline

# %%
from numpy.random import randn
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0  1.695643
# 1     1  3.686861
# 2     2  3.291723
# 3     3  2.632871
# 4     4  1.306951

# %%
sb.relplot(x="time", y="value", kind = "line", data = df)
