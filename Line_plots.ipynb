# %%
import pandas as pd
import seaborn as sb
import numpy as np 
import matplotlib.pyplot as plt 


# %matplotlib inline

# %%
from numpy.random import randn
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0 -0.374790
# 1     1  0.031438
# 2     2  0.562883
# 3     3  3.055816
# 4     4  2.199782

# %%
sb.relplot(x="time", y="value", kind = "line", data = df, sort= True)

# %%
df = pd.DataFrame(randn(500,2).cumsum(axis =0), columns= ["time", "value"])
df.head()
sb.relplot(x="time", y="value", kind = "line", data = df, sort= False)
# ASK QUESTION ABOUT SORT

# %%
fmri = sb.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sb.relplot(x= "timepoint", y= "signal", kind= "line", data= fmri)
#The shady line is 95% of confidence, means that in 95% the signal is between this lines
#ci = False to  cancel this line

# %%
sb.relplot(x= "timepoint", y= "signal", kind= "line", data= fmri, ci = "sd")
#sd means standart daviation

# %%
sb.relplot(x= "timepoint", y= "signal", estimator =None, kind= "line", data= fmri)

# %%
sb.relplot(x= "timepoint", y= "signal", hue = "event", kind= "line", data= fmri)
#hue added

# %%
sb.relplot(x= "timepoint", y= "signal", hue = "region",style = "event",kind= "line", data= fmri, markers=True,ci=50, err_style="bars")
#ci = 50  
#err_style = "bars"

# %%
sb.lineplot(x="timepoint", y="signal", hue="event", units="subject",estimator=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-a740c17d24b9> in <module>
# ----> 1 sb.lineplot(x="timepoint", y="signal", hue="event", units="subject",estimator=None)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1129         dashes=dashes, markers=markers, style_order=style_order,
#    1130         units=units, estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# -> 1131         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1132     )
#    1133
#
# ...

# %%
iris = sb.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris = sb.load_dataset("iris")
sb.scatterplot(x= "sepal_length" , y="petal_length")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-38f46daaa9c7> in <module>
#       1 iris = sb.load_dataset("iris")
# ----> 2 sb.scatterplot(x= "sepal_length" , y="petal_length")
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1400         x_bins=x_bins, y_bins=y_bins,
#    1401         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1402         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1403     )
#    1404
#
# ...

# %%
sb.relplot(x= "timepoint", y= "signal", hue = "region",style = "event",kind= "line", data= fmri,markers= True, dashes=False)

# %%
sb.relplot(x= "timepoint", y= "signal", hue = "event", style = "event",kind= "line", data= fmri,markers= True, dashes=False)
#hue and style changet to "event"

# %%
sb.relplot(x="timepoint", y="signal", hue="region", units = "subject", estimator = None, kind="line", data= fmri.query("event == 'stim'"))

# %%
dots = sb.load_dataset("dots").qurry("align == 'dots'")
dots.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-b6dd64b649a1> in <module>
# ----> 1 dots = sb.load_dataset("dots").qurry("align == 'dots'")
#       2 dots.head()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'qurry'

# %%
palette = sb.cubehelix_palette(rot=-.4)# to make different colors 
sb.relplot(x = "time", y = "firing_rate", data= dots, kind= "line", hue= "coherence", style = "choice", palette=palette)

# %%
palette = sb.cubehelix_palette(rot=-.4)# to make different colors 
sb.relplot(x = "time", y = "firing_rate", size="coherence", hue="coherence", data= dots, kind= "line",  style = "choice", palette=palette, sizes =(1,10)) #size added to make the lines fatter and sizes added

# %%
df= pd.DataFrame(dict(time=pd.date_range("2019-06-02", periods =500),value = randn(500).cumsum()))
df.head()
# Out:
#         time     value
# 0 2019-06-02  0.300195
# 1 2019-06-03 -0.582626
# 2 2019-06-04 -0.272900
# 3 2019-06-05  0.304432
# 4 2019-06-06 -1.122833

# %%
g = sb.relplot(x="time", y="value",kind="line", data=df )
g.fig.autofmt_xdate()

# %%
tips = sb.load_dataset("tips")
sb.relplot(x="total_bill", y="tip", hue= "smoker", col="size", data= tips,col_wrap=3)
#here we cansee the size of group with cal_wrap=3

# %%
sb.scatterplot(x="sepal_length", y="petal_length", data=iris)

# %%
sb.relplot(x= "timepoint", y= "signal", hue = "subject", col="region", row="event", height=3, kind="line", estimator=None, data= fmri)

# %%
sb.lineplot(x="total_bill", y="tip", data=tips)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sb.lineplot(x="timepoint", y="signal", data=fmri, hue="region", style = "event",)
